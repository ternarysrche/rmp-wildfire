# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata
import shapely
import matplotlib.colors as colors
from IPython.display import clear_output
from tqdm.notebook import tqdm
import time
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /var/folders/xt/52zb2sgj4q9f84tyf9cg1yf00000gn/T/ipykernel_4147/4175728622.py:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
stations = geopandas.read_file("./mygeodata/fire_station_point.geojson")

# %%
jsonfile = ('/Users/christopher/Downloads/ark28722-s73w23-geojson.json')
world = geopandas.read_file(jsonfile)

# %%
ax = world.plot(color = "none", edgecolor = 'black', figsize = (12,8))
plt.autoscale(False)
plt.axis('off')
stations.plot(ax = ax, color = "green", markersize=1)
# Out:
# <Axes: >

# %%
len(stations)
# Out:
# 1143
