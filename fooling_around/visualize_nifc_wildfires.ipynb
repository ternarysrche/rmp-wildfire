# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /var/folders/xt/52zb2sgj4q9f84tyf9cg1yf00000gn/T/ipykernel_84581/2676932518.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv('/Users/christopher/Documents/Wildfires/drive-download-20230629T154135Z-001/Wildland_Fire_Incident_Locations_csv.csv')
# Out:
# /var/folders/xt/52zb2sgj4q9f84tyf9cg1yf00000gn/T/ipykernel_84581/468546253.py:1: DtypeWarning: Columns (6,7,15,16,34,63,66,79,87,88,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/christopher/Documents/Wildfires/drive-download-20230629T154135Z-001/Wildland_Fire_Incident_Locations_csv.csv')

# %%
len(df)
# Out:
# 265312

# %%
for i in df.columns:
    print(i, df[i].isnull().sum())
# Out:
# X 0
# Y 0
# OBJECTID 0
# SourceOID 0
# ABCDMisc 251888
# ADSPermissionState 0
# ContainmentDateTime 106121
# ControlDateTime 122630
# CreatedBySystem 0
# IncidentSize 78029
# DiscoveryAcres 66588
# DispatchCenterID 37378
# EstimatedCostToDate 250156
# FinalAcres 244455
# FinalFireReportApprovedByTitle 265312
# FinalFireReportApprovedByUnit 262696
# FinalFireReportApprovedDate 232008
# FireBehaviorGeneral 248411
# FireBehaviorGeneral1 258104
# FireBehaviorGeneral2 259103
# FireBehaviorGeneral3 261342
# FireCause 32748
# FireCauseGeneral 208593
# FireCauseSpecific 249133
# FireCode 132673
# FireDepartmentID 254284
# FireDiscoveryDateTime 0
# FireMgmtComplexity 241581
# FireOutDateTime 115064
# FireStrategyConfinePercent 257590
# FireStrategyFullSuppPercent 255394
# FireStrategyMonitorPercent 257481
# FireStrategyPointZonePercent 257856
# FSJobCode 196115
# FSOverrideCode 196745
# GACC 62
# ICS209ReportDateTime 251848
# ICS209ReportForTimePeriodFrom 252188
# ...

# %%
df.head()
# Out:
#             X          Y  OBJECTID  SourceOID ABCDMisc ADSPermissionState  \
# 0 -118.180712  33.808985         1    7747595      NaN            DEFAULT
# 1 -117.153901  33.176394         2    6384391      NaN            DEFAULT
# 2 -121.104180  38.834727         3    1383752      NaN            DEFAULT
# 3 -117.228592  33.782442         4   22499589      NaN            DEFAULT
# 4 -118.309032  33.941815         5   23869477      NaN            DEFAULT
#
#   ContainmentDateTime ControlDateTime CreatedBySystem  IncidentSize  ...  \
# 0                 NaN             NaN         lacocad           NaN  ...
# 1                 NaN             NaN        firecode           NaN  ...
# 2                 NaN             NaN        firecode           NaN  ...
# 3                 NaN             NaN           cfcad           NaN  ...
# 4                 NaN             NaN         lacocad           NaN  ...
#
#    EstimatedFinalCost OrganizationalAssessment  StrategicDecisionPublishDate  \
# ...

# %%
import matplotlib.pyplot as plt
import geopandas
# states = geopandas.read_file('/Users/christopher/Documents/Wildfires/drive-download-20230629T154135Z-001/Wildland_Fire_Incident_Locations/Incidents.shp')
# type(states)
zipfile = ('zip:///Users/christopher/Documents/Wildfires/drive-download-20230629T154135Z-001/Wildland_Fire_Incident_Locations.zip')
df = geopandas.read_file(zipfile)

# %%
print(df['geometry'].y)
# Out:
# 33.80898483300007

# %%
states.head()
# Out:
#    OBJECTID  SourceOID ABCDMisc ADSPermiss Containmen ControlDat CreatedByS  \
# 0         1    7747595      NaN    DEFAULT        NaN        NaN    lacocad
# 1         2    6384391      NaN    DEFAULT        NaN        NaN   firecode
# 2         3    1383752      NaN    DEFAULT        NaN        NaN   firecode
# 3         4   22499589      NaN    DEFAULT        NaN        NaN      cfcad
# 4         5   23869477      NaN    DEFAULT        NaN        NaN    lacocad
#
#    IncidentSi  DiscoveryA DispatchCe  ...  Organizati  StrategicD  CreatedOnD  \
# 0         NaN        0.10     CALACC  ...         NaN         NaN  2020-02-28
# 1         NaN         NaN     CAMVIC  ...         NaN         NaN  2019-07-01
# 2         NaN         NaN        NaN  ...         NaN         NaN  2016-06-20
# 3         NaN        0.10     CARRCC  ...         NaN         NaN  2021-11-25
# 4         NaN        0.01     CALACC  ...         NaN         NaN  2022-11-21
#
# ...

# %%
df.sort_values("CreatedOnD")
# Out:
#         OBJECTID  SourceOID ABCDMisc ADSPermiss  Containmen  ControlDat  \
# 232035    272667     502210      NaN    DEFAULT  2014-05-20  2014-05-20
# 105652    111990     500927      NaN    DEFAULT  2014-04-11  2014-04-11
# 220465    258006     501449      NaN    DEFAULT         NaN         NaN
# 133474    147296     501431      NaN    DEFAULT  2014-05-03  2014-05-03
# 90920      93215     500924      NaN    DEFAULT  2014-05-21  2014-05-21
# ...          ...        ...      ...        ...         ...         ...
# 265305    317295   28037617      NaN    DEFAULT         NaN         NaN
# 265304    317294   28037619      NaN    DEFAULT  2023-06-29         NaN
# 265303    317293   28037618      NaN    DEFAULT         NaN         NaN
# 265306    317297   28037622      NaN    DEFAULT         NaN         NaN
# 265311    317302   28037626      NaN    DEFAULT         NaN         NaN
#
#        CreatedByS  IncidentSi  DiscoveryA DispatchCe  ...  Organizati  \
# ...

# %%
type(df["CreatedOnD"][0])
# Out:
# str

# %%
world["geometry"][0][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 world["geometry"][0][0]
#
# TypeError: 'LineString' object is not subscriptable

# %%
# from shapely.geometry import Point, LineString, Polygon
jsonfile = ('/Users/christopher/Downloads/ark28722-s73w23-geojson.json')
world = geopandas.read_file(jsonfile)
world.plot(color="white", edgecolor = "black")
# Out:
# <Axes: >

# %%
df['geometry']
# Out:
# 0         POINT (-118.18071 33.80898)
# 1         POINT (-117.15390 33.17639)
# 2         POINT (-121.10418 38.83473)
# 3         POINT (-117.22859 33.78244)
# 4         POINT (-118.30903 33.94181)
#                      ...
# 265307    POINT (-120.49029 46.36028)
# 265308    POINT (-109.42911 40.37901)
# 265309    POINT (-120.03705 39.84382)
# 265310    POINT (-121.40671 41.19282)
# 265311    POINT (-111.74086 33.00334)
# Name: geometry, Length: 265312, dtype: geometry

# %%
# x = []
# y = []
# for i in df.query("(POOState == 'US-CA') & ()")["geometry"]:
#     x.append(i.x)
#     y.append(i.y)
# x = np.array(x)
# y = np.array(y)

# %%
# gdf = geopandas.GeoDataFrame(
#     df, geometry=geopandas.points_from_xy(df['geometry'].x, df['geometry'].y)
# )
# %matplotlib notebook
from scipy.stats import kde
from tqdm.notebook import tqdm
import numpy as np
# ax = world.plot(color="white", edgecolor="black")



ax = world.plot(color = "white",edgecolor = 'black', figsize = (10,10))
df.query("(POOState == 'US-CA')").plot(ax = ax, figsize=(10,10), color='red', marker='x', markersize=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
# gdf = geopandas.GeoDataFrame(
#     df, geometry=geopandas.points_from_xy(df['geometry'].x, df['geometry'].y)
# )
# %matplotlib inline
from scipy.stats import kde
from tqdm.notebook import tqdm
from IPython.display import display, clear_output
import numpy as np
import time
# ax = world.plot(color="white", edgecolor="black")
year = 2014
while (True):
    ax = world.plot(color = "white",edgecolor = 'black', figsize = (10,10))
    df.query("(POOState == 'US-CA') & (CreatedOnD > '{}-00-00') & (CreatedOnD < '{}-00-00')".format(year, year+1)).plot(ax = ax, figsize=(10,10), color='red', marker='x', markersize=0.5)
    plt.title(str(year) + "-" + str(year+1))
    plt.show()
    time.sleep(0.5)
    clear_output(wait=True)
    year += 1
    if (year == 2024):
        year = 2014
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 year = 2014
#      12 while (True):
# ---> 13     ax = world.plot(color = "white",edgecolor = 'black', figsize = (10,10))
#      14     df.query("(POOState == 'US-CA') & (CreatedOnD > '{}-00-00') & (CreatedOnD < '{}-00-00')".format(year, year+1)).plot(ax = ax, figsize=(10,10), color='red', marker='x', markersize=0.5)
#      15     plt.title(str(year) + "-" + str(year+1))
#
# File ~/anaconda3/lib/python3.10/site-packages/geopandas/plotting.py:969, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     967 kind = kwargs.pop("kind", "geo")
#     968 if kind == "geo":
# --> 969     return plot_dataframe(data, *args, **kwargs)
#     970 if kind in self._pandas_kinds:
#     971     # Access pandas plots
#     972     return PlotAccessor(data)(kind=kind, **kwargs)
#
# ...

# %%
# gdf = geopandas.GeoDataFrame(
#     df, geometry=geopandas.points_from_xy(df['geometry'].x, df['geometry'].y)
# )
# %matplotlib inline
from scipy.stats import kde
from tqdm.notebook import tqdm
from IPython.display import display, clear_output
import numpy as np
import time
# ax = world.plot(color="white", edgecolor="black")
year = 2014
while (True):
    ax = world.clip([-119,33,-117,35]).plot(color = "white",edgecolor = 'black', figsize = (10,10))
    df.query("(POOState == 'US-CA') & (CreatedOnD > '{}-00-00') & (CreatedOnD < '{}-00-00')".format(year, year+1)).clip([-119,33,-117,35]).plot(ax = ax, figsize=(10,10), color='red', marker='x', markersize=0.5)
    plt.title(str(year) + "-" + str(year+1))
    plt.show()
    time.sleep(0.5)
    clear_output(wait=True)
    year += 1
    if (year == 2024):
        year = 2014
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[162], line 17
#      15 plt.title(str(year) + "-" + str(year+1))
#      16 plt.show()
# ---> 17 time.sleep(0.5)
#      18 clear_output(wait=True)
#      19 year += 1
#
# KeyboardInterrupt:

# %%
geopandas.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
# gdf = geopandas.GeoDataFrame(
#     df, geometry=geopandas.points_from_xy(df['geometry'].x, df['geometry'].y)
# )
# %matplotlib notebook
from scipy.stats import kde
from tqdm.notebook import tqdm
import numpy as np
import math
import matplotlib


ax = world.plot(color = "white",edgecolor = 'black', figsize = (10,10))
df.query("POOState == 'US-CA'").plot(ax = ax, figsize=(10,10), color='red', marker='x', markersize=0.5)
circle_range = matplotlib.patches.Ellipse((-118,34), 0.07/math.cos(35), 0.07, color='blue')
ax.add_patch(circle_range)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
# steps_per_deg = 10
# start_lat = 30
# end_lat = 42
# start_long = -125
# end_long = -113
# dens = [[0 for j in range(-start_long*steps_per_deg, -end_long*steps_per_deg, 1)] for i in range(start_lat*steps_per_deg,end_lat*steps_per_deg,1)]
# def fill_cell(x,y, ax=None, **kwargs):
#     global steps_per_deg
#     rect = plt.Rectangle((x-1/steps_per_deg, y-1/steps_per_deg), 1/steps_per_deg,1/steps_per_deg, fill=True, **kwargs)
#     ax = ax or plt.gca()
#     ax.add_patch(rect)
#     return rect
# for i in tqdm(range(0,(end_lat-start_lat)*steps_per_deg)):
#     for j in range(0,(end_long-start_long)*steps_per_deg):
# #         dens[i][j] = 
#         fill_cell(i,j,alpha=len(df[(df.geometry.x + 1/steps_per_deg > i*1/steps_per_deg + start_lat) & (df.geometry.x < i*1/steps_per_deg + start_lat) & (df.geometry.y + 1/steps_per_deg > j*1/steps_per_deg + start_long) & (df.geometry.y < j*1/steps_per_deg + start_long)]))
# # def heatmap2d(arr: np.ndarray):
# #     plt.imshow(arr, cmap='viridis')
# #     plt.colorbar()
# #     plt.show()
