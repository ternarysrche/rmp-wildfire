# %%
import requests
import json
json_years = {}
for year in range(2000, 2024):
    try:
        response = requests.get("https://incidents.fire.ca.gov/umbraco/api/IncidentApi/GeoJsonList?year=" + str(year))
        json_years[year] = response.json()
        print(year, len(response.json()["features"]))
    except E:
        print(year, E)
# Out:
# 2000 0
# 2001 0
# 2002 0
# 2003 10
# 2004 21
# 2005 14
# 2006 79
# 2007 73
# 2008 55
# 2009 72
# 2010 66
# 2011 124
# 2012 134
# 2013 159
# 2014 115
# 2015 157
# 2016 184
# 2017 436
# 2018 310
# 2019 264
# 2020 258
# 2021 186
# 2022 151
# 2023 31

# %%
import pandas as pd
import geopandas
fires_gdf = geopandas.GeoDataFrame()
for year in range(2003, 2024):
    fires_temp = geopandas.GeoDataFrame.from_features(json_years[year]["features"])
    fires_gdf = geopandas.GeoDataFrame(pd.concat([fires_gdf, fires_temp], ignore_index=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 fires_gdf = geopandas.GeoDataFrame()
#       4 for year in range(2003, 2024):
# ----> 5     fires_temp = geopandas.GeoDataFrame.from_features(json_years[year]["features"])
#       6     fires_gdf = geopandas.GeoDataFrame(pd.concat([fires_gdf.to_crs('epsg:4326'), fires_temp.to_crs('epsg:4326')], ignore_index=True))
#
# NameError: name 'json_years' is not defined

# %%
fires_gdf = geopandas.GeoDataFrame(
    fires_gdf, geometry=geopandas.points_from_xy(fires_select.Longitude, fires_select.Latitude), crs="EPSG:4326"
)

# %%
print(fires_gdf.crs)
# Out:
# EPSG:4326

# %%
fires_select = fires_gdf
fires_plot = fires_select.to_crs(world.crs).clip(world)

# %%
import matplotlib.pyplot as plt
fires_plot.plot()
# Out:
# <Axes: >

# %%
# fires_select = fires_gdf[(fires_gdf.Latitude < 44) & (fires_gdf.Latitude > 30) & (fires_gdf.Longitude < -113) & (fires_gdf.Longitude > -125)]
# fires_select = fires_select[~fires_select["AcresBurned"].isnull()]
# fires_select["AcresBurned"].replace(to_replace = 0, value = 1, inplace=True)

# %%
jsonfile = ('/Users/christopher/Downloads/ark28722-s73w23-geojson.json')
world = geopandas.read_file(jsonfile)

# %%
import numpy as np
ax = world.plot(color = "none",edgecolor = 'black', figsize = (10,10))
plt.scatter(fires_plot["Longitude"], fires_plot["Latitude"], c=np.log(fires_plot["AcresBurned"]), cmap="Reds", s=4)
plt.show()
# Out:
# /Users/christopher/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fires_plot["Started"]
# Out:
# 2583    2021-06-09T13:53:00Z
# 1305    2017-05-25T18:15:00Z
# 2244    2019-10-22T19:20:44Z
# 2320    2020-06-09T21:51:40Z
# 1684    2017-10-13T15:40:00Z
#                 ...
# 1529    2017-08-13T12:41:00Z
# 2050    2019-06-16T20:33:00Z
# 1164    2016-07-19T14:09:00Z
# 1562    2017-08-29T15:39:00Z
# 991     2015-07-21T17:00:00Z
# Name: Started, Length: 2062, dtype: object

# %%
fires_plot["geometry"]
# Out:
# 2583    POINT (-117.34832 33.31571)
# 1305    POINT (-117.39818 33.34988)
# 2244    POINT (-117.40372 33.35115)
# 2320    POINT (-117.47166 33.37579)
# 1684    POINT (-117.46709 33.38613)
#                    ...
# 1529    POINT (-122.94010 41.99279)
# 2050    POINT (-122.40157 41.94622)
# 1164    POINT (-122.59328 41.96191)
# 1562    POINT (-121.90077 41.99483)
# 991     POINT (-121.89123 41.99934)
# Name: geometry, Length: 2062, dtype: geometry

# %%
fires_plot.to_file('california_fires.geojson', driver='GeoJSON')

# %%
import requests
response = requests.get("https://incidents.fire.ca.gov/umbraco/api/IncidentApi/GeoJsonList?year=2015")
print(len(response.json()))
# Out:
# 2

# %%
import requests
response = requests.get("https://incidents.fire.ca.gov/umbraco/api/IncidentApi/GeoJsonList?year=2016")
print(len(response.json()))
# Out:
# 2

# %%
import requests
response = requests.get("https://incidents.fire.ca.gov/umbraco/api/IncidentApi/GeoJsonList?year=2003")
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}, 'properties': {'Name': 'Paradise Fire', 'Final': True, 'Updated': '2003-11-06T07:00:00Z', 'Started': '2003-10-26T01:30:00Z', 'AdminUnit': 'CDF San Diego Unit', 'AdminUnitUrl': None, 'County': 'San Diego', 'Location': 'Valley Center', 'AcresBurned': 56700.0, 'PercentContained': 100.0, 'ControlStatement': 'Expected control November 15, 2003 at 8 a.m.', 'AgencyNames': 'CDF San Diego Unit, CDF, US Forest Service, Dept. Fish and Game, local government agencies', 'Longitude': 0.0, 'Latitude': 0.0, 'Type': '', 'UniqueId': 'a439b26e-4f99-41f5-9ac2-625b5a98bade', 'Url': 'https://incidents.fire.ca.gov/incidents/2003/10/26/paradise-fire/', 'ExtinguishedDate': '2003-11-06T07:00:00Z', 'ExtinguishedDateOnly': '2003-11-06', 'StartedDateOnly': '2003-10-26', 'IsActive': False, 'CalFireIncident': True, 'NotificationDesired': False}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}, 'properties': {'Name': 'Cedar Fire', 'Final': True, 'Updated': '2003-11-05T06:00:00Z', 'Started': '2003-10-25T17:37:00Z', 'AdminUnit': 'Cleveland National Forest/CDF San Diego Unit', 'AdminUnitUrl': None, 'County': 'San Diego', 'Location': 'Southern San Diego County', 'AcresBurned': 273246.0, 'PercentContained': 100.0, 'ControlStatement': 'Estimate for control is November 16, 2003 at 6 p.m', 'AgencyNames': 'Cleveland National Forest/CDF San Diego Unit, CDF, U.S. Forest Service, Local Government', 'Longitude': 0.0, 'Latitude': 0.0, 'Type': '', 'UniqueId': '87df7ff8-30a4-4d0d-9f81-9252b972b9e8', 'Url': 'https://incidents.fire.ca.gov/incidents/2003/10/25/cedar-fire/', 'ExtinguishedDate': '2003-11-05T06:00:00Z', 'ExtinguishedDateOnly': '2003-11-05', 'StartedDateOnly': '2003-10-25', 'IsActive': False, 'CalFireIncident': True, 'NotificationDesired': False}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}, 'properties': {'Name': 'Simi Fire', 'Final': True, 'Updated': '2003-11-05T10:00:00Z', 'Started': '2003-10-25T14:15:00Z', 'AdminUnit': 'Ventura County', 'AdminUnitUrl': None, 'County': 'Ventura', 'Location': 'Simi Valley / Moorpark', 'AcresBurned': 108204.0, 'PercentContained': 100.0, 'ControlStatement': '100%', 'AgencyNames': 'Ventura County, Ventura Co. Fire, CDF, Los Angeles Co. Fire, Los Angeles City Fire, Kern Co. Fire, Santa Barbara Co. Fire, CHP, Ventura Co. Sher', 'Longitude': 0.0, 'Latitude': 0.0, 'Type': '', 'UniqueId': 'e2b80ea7-d8e5-41b3-a07a-7c1ae763be48', 'Url': 'https://incidents.fire.ca.gov/incidents/2003/10/25/simi-fire/', 'ExtinguishedDate': '2003-11-05T10:00:00Z', 'ExtinguishedDateOnly': '2003-11-05', 'StartedDateOnly': '2003-10-25', 'IsActive': False, 'CalFireIncident': True, 'NotificationDesired': False}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}, 'properties': {'Name': 'Mountain Fire', 'Final': True, 'Updated': '2003-10-30T06:00:00Z', 'Started': '2003-10-26T11:45:00Z', 'AdminUnit': 'CDF Riverside Unit/Riverside County Fire', 'AdminUnitUrl': None, 'County': 'Riverside', 'Location': 'Sage Area', 'AcresBurned': 10331.0, 'PercentContained': 100.0, 'ControlStatement': 'Control expected on November 2, 2003 at 6:00 p.m.', 'AgencyNames': 'CDF Riverside Unit/Riverside County Fire, CDF, Riverside County, CHP', 'Longitude': 0.0, 'Latitude': 0.0, 'Type': '', 'UniqueId': '6d9d1c38-38b9-4820-a45e-c067fdfafe66', 'Url': 'https://incidents.fire.ca.gov/incidents/2003/10/26/mountain-fire/', 'ExtinguishedDate': '2003-10-30T06:00:00Z', 'ExtinguishedDateOnly': '2003-10-30', 'StartedDateOnly': '2003-10-26', 'IsActive': False, 'CalFireIncident': True, 'NotificationDesired': False}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]}, 'properties': {'Name': 'Otay Fire', 'Final': True, 'Updated': '2019-07-01T13:05:56Z', 'Started': '2003-10-26T13:00:00Z', 'AdminUnit': 'CDF San Diego Unit', 'AdminUnitUrl': None, 'County': 'San Diego', 'Locat ...
